# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Pyplot Básico

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(0,5,11)
y=x**2
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
plt.plot(x,y) #Creo el gráfico
plt.show() #ploteo el gráfico

# %%
plt.plot(x,y,'r') #Puedo costumizar la gráfica con atributos, en este caso el color

# %%
plt.plot(x,y,'bo') #Puedo costumizar la gráfica con atributos, en este caso el color y tipo de linea
plt.show()

# %%
plt.plot(x, y, color = 'orange')
plt.show()

# %% [markdown]
# Si quisieran utilizar el color naranja no se puede utilizar la letra ‘o’, ya que está sirve para los círculos, en su lugar tendrían que utilizar una de los siguiente métodos
#
#
#
# ```
# plt.plot(x, y, color = 'orange')
# ```
#
#
# También se puede especificar el color utilizando el código HEX o RGB
#
#
#
# ```
# plt.plot(x, y, color = 'FFA500') #Código HEX
# plt.plot(x, y, color = [1.0, 0.5, 0.25]) #Código RGB
# ```

# %%
plt.plot(x,y,'rx') #Puedo costumizar la gráfica con atributos, en este caso el color y tipo de linea
#Muy similar a como funciona en Matlab

# %%
plt.plot(x,y,'rs-') #Puedo costumizar la gráfica con atributos, en este caso el color y tipo de linea
#squad (cuadrado) y linea

# %%
plt.plot(x,y,'gD:') #Puedo costumizar la gráfica con atributos, en este caso el color y tipo de linea
#verde Diamantes y linea punteada

# %%
plt.hist(x) #crea un histograma
plt.show()

# %%
plt.pie(x) #grafico de torta
plt.show()

# %%
plt.scatter(x,y) #crea un hscatterplot
plt.show()

# %%
plt.boxplot(x) #crea un grafico de cajas y bigotes para ver la distribución
plt.show()

# %% [markdown]
# ## Subplot
# Me permite generar más visualizaciones de acuerdo a mis necesidades

# %%
plt.subplot(1,2,1) #tres parametros, numero de filas, n de columnas, index que voy a manejar entre filas y columnas
plt.plot(x,y,'g--') #que quiero en ese grafico que defini
plt.subplot(1,2,2) #en el segundo grafico en index es el 2
plt.hist(y) #definicion del segundo grafico
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.subplot(1,2,1) #tres parametros, numero de filas, n de columnas del arreglo grafico y el tercer valor es el index que voy a manejar entre filas y columnas
#es decir ese tercer parámetro indica donde estará este primer gráfico, en este caso indice 1
plt.plot(x,y,'g--') #que quiero en ese grafico que defini
plt.plot(y,x,'b:') #Todo lo que ponga bajo la definición del arreglo grafico saldrá en ese indice (1)
plt.subplot(1,2,2) #en el segundo grafico en index 2
plt.pie(y) #definicion del segundo grafico que saldrá en la posición (2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Modificando disposición de los graficos, ojo con el manejo de los index
plt.subplot(2,1,1)
plt.plot(x,y,'g--')
plt.plot(x,x,'g--')
plt.plot(y,x,'r:')
plt.subplot(2,1,2)
plt.pie(y)
plt.show()

# %% [markdown]
# ## Método Orientado a Objetos
#
# Más constumizable, más a amigable a más diagramas, requiere más código

# %%
from matplotlib import axes
#Primero creo el linezo donde vaa a estar mi gráfica
fig = plt.figure()

#Nuestro gráficos serán los "axes", a los cuales le agregamos
axes=fig.add_axes([0.1,0.1,0.5,0.9])
axes.plot(x,y,'b')
fig.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_24432\4203024508.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#La ventaja viene cuando quiero hacer algo mucho más especifico
fig = plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.9])
#los dos primero parámetros hacen referencia a la posición de la figura en el lienzo
#los siguientes 2, definen el tamaño del axes (gráfico) en el lienzo (horizontal,vertical)
axes2=fig.add_axes([0.99,-0.65,0.4,0.3]) #para hacer un segundo gráfico

axes.plot(x,y,'b')
axes2.plot(y,x,'g')
axes2.set_facecolor('lightgray') #así puedo modificar el color de fondo de ese axes
#Esta es una ventaja de usar método orientado a objeto, cada objeto es distinto y lo puedo modificar por separado

fig.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_2624\4161390303.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_2624\2714581593.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(2,2))

# %% [markdown]
# ## Subplots
#
# Con "s" al final utiliza las bondades de Orientado a Objetos

# %%
x = np.linspace(0,5,12)
y = np.sin(x)
print(x)
print(y)
# Out:
# [0.         0.45454545 0.90909091 1.36363636 1.81818182 2.27272727
#  2.72727273 3.18181818 3.63636364 4.09090909 4.54545455 5.        ]
# [ 0.          0.43905397  0.78894546  0.978619    0.96955595  0.76359681
#   0.40256749 -0.04021468 -0.47483011 -0.8130177  -0.98609877 -0.95892427]

# %%
fig, axes = plt.subplots() #Defino el lienzo
axes.plot(x,y,'b')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2) #Defino el lienzo y agrego atributos
#Definí un lienzo con una fila y dos columnas

# %%
fig, axes = plt.subplots(nrows=1, ncols=2) #Defino el lienzo y agrego atributos. fig se define como el lienzo y los axes como las figuras nrows el numero de filas
#Y ncols como el numero de comlumnas 
axes[0].plot(x,y,'b') #puedo acceder al axes por su index, pues es una especie de array
axes[1].plot(y,x*100,'g')

# %%
#Hay otra forma de configurar estos gráficos
#Dado que los axes son definidos como tuplas o array
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2) #los defino al definir el lienzo
ax1.plot(x,y,'b') #luego accedo directamente
ax2.plot(y,x*100,'g')

# %%
fig, axes = plt.subplots(2, 4)
axes[0,0].plot(x,np.cos(x),'b')
axes[0,1].plot(x,np.tan(x),'g')
axes[0,2].plot(x,np.tan(y),'b')
axes[0,3].plot(x,np.sin(x)*np.sqrt(np.tan(x))/np.tan(y),'r')

axes[1,0].plot(x,np.cos(y),'orange')
axes[1,1].plot(x,np.sqrt(x),'g')
axes[1,2].plot(x,np.tan(y)**3,'b')
axes[1,3].plot(x,np.sin(x)**-1,'gray')

fig.tight_layout() #Esto es para organizar mejor el lienzo
#Todo esto lo puedo también definir por tuplas como en el ejemplo anterior
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_2624\2268895419.py:5: RuntimeWarning: invalid value encountered in sqrt
#   axes[0,3].plot(x,np.sin(x)*np.sqrt(np.tan(x))/np.tan(y),'r')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_2624\2268895419.py:5: RuntimeWarning: invalid value encountered in divide
#   axes[0,3].plot(x,np.sin(x)*np.sqrt(np.tan(x))/np.tan(y),'r')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_2624\2268895419.py:10: RuntimeWarning: divide by zero encountered in reciprocal
#   axes[1,3].plot(x,np.sin(x)**-1,'gray')

# %% [markdown]
# ## Leyendas, Etiquetas, Titulos y Tamaño

# %%
from IPython.core.pylabtools import figsize
fig, axes=plt.subplots(1,2,figsize=(12,8)) #Con este último parámetro defino el tamaño del lienzo/figura
axes[0].plot(x,y, label='$sen(x)$') #Con este tercer parámetro puedo agregar un label a la gráfica
#Con el $ se pone como notación matemática
axes[0].set_title('Relación X - Y') #Para poner Titulo al gráfico
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')
axes[0].legend() #Esto es necesario para que aparezca la legenda y en ella aparecerán las label que definí antes
axes[1].plot(y,x,)
axes[1].set_title('Relación Y - X')
axes[1].set_xlabel('Y')
axes[1].set_ylabel('X')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 3
#       1 from IPython.core.pylabtools import figsize
#       2 fig, axes=plt.subplots(1,2,figsize=(12,8)) #Con este último parámetro defino el tamaño del lienzo/figura
# ----> 3 axes[0].plot(x,y, label='$sen(x)$') #Con este tercer parámetro puedo agregar un label a la gráfica
#       4 #Con el $ se pone como notación matemática
#       5 axes[0].set_title('Relación X - Y') #Para poner Titulo al gráfico
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
# ...

# %%
#Cómo se haría sin Orientacion a Objetos
plt.plot(x,y,label='sin(x')
plt.title('Este es un Titulo')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='lower left', bbox_to_anchor=(0.8,0.5)) #asi defino la posición de la legend y con el bbox puedo especificar cualquier punto del layout

# %% [markdown]
# ## Colores y Estilos

# %%
print(plt.style.available) #Me trae los estilos que puedo usar por default
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
for x in plt.style.available:
      plt.style.use(x)
      fig, ax = plt.subplots(figsize=(2,2))
      ax.set_title(x, size=20)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_2624\2714581593.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(2,2))

# %%
#veamos en que consisten
plt.style.use('seaborn')
fig, ax =plt.subplots(figsize=(8,9))
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_2624\4259997030.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# ### Modificaciones tipo Matlab

# %%
plt.style.use('seaborn-poster') #Puedo cambiar los estilos
fig, ax =plt.subplots(figsize=(8,9))
#ax.plot(x,np.sqrt(x*2+1)*np.tan(x),'g:')#
#ax.plot(x,x+2,'b--')
#ax.plot(x,x*3,'r.-')
ax.plot(x,x**2,'yo')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_2624\1947246292.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster') #Puedo cambiar los estilos
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 6
#       2 fig, ax =plt.subplots(figsize=(8,9))
#       3 #ax.plot(x,np.sqrt(x*2+1)*np.tan(x),'g:')#
#       4 #ax.plot(x,x+2,'b--')
#       5 #ax.plot(x,x*3,'r.-')
# ----> 6 ax.plot(x,x**2,'yo')
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %% [markdown]
# ### Modificaciones con Pyplot

# %%
plt.style.use('tableau-colorblind10') #Puedo cambiar los estilos
fig, ax =plt.subplots(figsize=(8,9))

ax.plot(x,np.sqrt(x*2+1)*np.tan(x),color='green',alpha=0.7) #Otra forma de definir el color, además puedo agregar opacidad con alpha
ax.plot(x,x+2,color='blue',alpha=0.7, linewidth=8) #Defnir el grosor de linea
ax.plot(x,x*3,color='#67FF66',alpha=0.7, linestyle= 'dashed') #Puedo acceder a RGB y otras definiciones de colores
ax.plot(x,x**2,color='#39FFCC',alpha=0.5, linestyle= 'dotted', marker='o', markersize=7, markerfacecolor=('r'))

# %% [markdown]
# ## Bar Plot
# Gráfico de barras

# %%
country = ['CHILE','ITALY','COLOMBIA','PERU','NUEVA ZELANDA']
population =[1200,300,4500,540,760]

# %%
plt.bar(country,population) #para generar el grafico de barras
plt.show
#Este tipo de graf tiene su variable x como categorica, es texto
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.bar(country,population, width=0.7, color='aquamarine') #puedo modif el ancho de las barras
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.style.use('seaborn-talk')
plt.bar(country,population, width=0.7, color=['aquamarine','turquoise']) #puedo alternar colores
plt.xticks(np.arange(5),('Chile','Italia','Colombia', 'Peru','Nueva Zelanda'),rotation=46)
#asi puedo personalizar aun más el eje x, accediendo a el, ojo que debo especificar el numero de entradas, en este caso (5)
#Incluso la inclinación con rotation
plt.title('Población por País', color='gray')
plt.xlabel('País', color='gray')
plt.ylabel('Población (miles)', color='gray')

plt.show
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14004\3710537409.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-talk')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.style.use('seaborn-talk')
plt.barh(country,population, color=['turquoise']) #barh para barras horizontales
plt.yticks(np.arange(5),('Chile','Italia','Colombia', 'Peru','Nueva Zelanda'),rotation=46)
#asi puedo personalizar aun más el eje y, accediendo a el, ojo que debo especificar el numero de entradas, en este caso (5)
#Incluso la inclinación con rotation
plt.title('Población por País', color='gray')
plt.xlabel('Población', color='gray')
plt.ylabel('País (miles)', color='gray')

plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.style.use('seaborn-talk')
#       2 plt.barh(country,population, color=['turquoise']) #barh para barras horizontales
#       3 plt.yticks(np.arange(5),('Chile','Italia','Colombia', 'Peru','Nueva Zelanda'),rotation=46)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Otro Tipo de Graficas

# %%
data = np.random.randint(1,50,100)

# %% [markdown]
# ### Histograma

# %%
plt.hist(data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Para agregar bins o barras, aumentar la densidad de barras en el histograma
#10 es el default
plt.hist(data,bins=60) #Puedo también modificar el ancho de las barras con width
#plt.hist(data,bins=60, width=2) #Puedo también modificar el ancho de las barras con width
#En su valor default trabaja bastante bien
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Puedo modificar el tipo de histograma
plt.hist(data,bins=10, histtype='bar')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Puedo modificar el tipo de histograma
plt.hist(data,bins=10, histtype='step')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.random.seed(19680801)

# example data
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(437)
'''
mu: Representa la media del conjunto de datos, en este caso 100.
sigma: Representa la desviación estándar, que indica la variabilidad de los datos respecto a la media, en este caso 15.
x: Creamos un array de tamaño 437 utilizando la función np.random.randn.
Esta función genera números aleatorios siguiendo una distribución normal (de Gauss) con media mu y desviación estándar sigma.
'''

num_bins = 50 #La variable num_bins define el número de barras que tendrá el histograma. En este caso, se usarán 50 barras para representar la distribución de los datos.



fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(x, num_bins, density=True)

'''
fig, ax: Se crea una nueva figura (fig) y un objeto de ejes (ax) para el histograma.
ax.hist: Se crea el histograma a partir de los datos en x, usando num_bins barras y la opción density=True para representar la densidad de probabilidad en lugar de conteos simples.
'''


# add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
'''
En estas líneas se añade una línea que representa la distribución normal (de Gauss) esperada con los valores de mu y sigma definidos anteriormente. 
La fórmula para calcular la curva se basa en la función de densidad de probabilidad de la distribución normal.

'''


ax.plot(bins, y, '--')
ax.set_xlabel('Smarts')
ax.set_ylabel('Probability density')
ax.set_title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

'''
e establecen las etiquetas para los ejes X (Smarts - Inteligencia) e Y (Probability density - Densidad de probabilidad). 
Además, se agrega un título al histograma que muestra la media (mu) y la desviación estándar (sigma) de la distribución.
'''

fig.tight_layout() # Esta línea utiliza la función fig.tight_layout para ajustar el espacio entre el histograma y las etiquetas, evitando que se superpongan.
plt.show()

# %% [markdown]
# ### Boxplot
# Ver cuartiles y analizar distribución con la media marcada

# %%
plt.boxplot(data)
plt.show()

# %%
#Para ver en horizontal
plt.boxplot(data, vert=False, patch_artist=True, notch=True) #con patch_artist agrego relleno para visualizar mejor el rango intercuartilico
#Con notch enfoco más la mediana
#vert viene de vertical y niega la verticalidad con false para obtorgar por default horontazilidad (creo que se escribe asi )
plt.show()

# %%
#Cuando tengo datos outlayers
data = np.append(data,98) #agrego un dato outlayer para visualizar
plt.boxplot(data, vert=False, patch_artist=True, notch=True)
plt.show()

# %%
data = np.append(data,98) #agrego un dato outlayer para visualizar
plt.boxplot(data, vert=False, patch_artist=True, notch=True, showfliers=False)
#Puedo no mostrar los outlayer, muy útil
plt.show()

# %% [markdown]
# ### Scatter
# Gráfico de dispersión

# %%
N= 50
x=np.random.rand(N)
y=np.random.rand(N)
area=(30*np.random.rand(N))**2
colors=np.random.rand(N)

# %%
plt.scatter(x,y)
plt.show()

# %%
#Puedo agregar atributos
plt.scatter(x,y, s=area, c=colors) #s plottea el área, c el color
plt.show()

# %%
#Puedo modificar los markers
plt.scatter(x,y, s=area, c=colors, marker='o', alpha=0.8)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # SEABORN

# %% [markdown]
# ## Set
# Parámetro con el que defino un tema, colores, fuentes y más

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x=['A','B','C'], y=[1,3,2])
plt.show() #Seaborn está construido sobre matplotlib, p1or lo que si escribo este código afecto a seaborn

# %%
#Definiendo set
sns.set(style='dark', palette='muted', font="Verdana", font_scale=1)
sns.barplot(x=['A','B','C'], y=[1,3,2])
plt.show()

# %% [markdown]
# ## Parámetros más usados con Seaborn

# %%
#Seaborn cuenta con distintos dataset de example para probar gráficas
tips=sns.load_dataset('tips') #Propinas en un restaurant
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(data=tips, x='total_bill')
plt.show() #Ojo que seaborn eligió el tipo de gráfico adhoc
# Out:
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=tips, x='total_bill', y='tip')
#En este caso que estoy relacionando dos variables lo cambió
plt.show()

# %%
sns.displot(data=tips, x='total_bill', y='tip', hue='sex')
#Otro parámetro es Hue, que hace un agrupamiento por cualquier otra variable
plt.show()

# %%
#También funciona en otros casos
sns.displot(data=tips, x='total_bill', hue='sex')

# %%
sns.displot(data=tips, x='total_bill', hue='sex', kind='kde') #La misma distribución del histograma, pero por densidad
#Para especificar con que tipo de gráfico quiero trabajar
plt.show()

# %%
sns.displot(data=tips, x='total_bill', hue='sex', kind='kde', legend='True', palette='dark', alpha=0.7)
#Legend funciona para todos los gráficos, además de paletas predefinidas y opacidad
plt.show()

# %% [markdown]
# ## Distribuciones

# %% [markdown]
# [documentation](https://seaborn.pydata.org/tutorial/distributions.html)

# %%
sns.histplot(data=tips, x='tip', bins=15, cumulative=False, hue='sex', stat='frequency')
#Puedo usar bins como en plt, por default son 15
#cumulative para ver el comportamiento acumulativo
#frequency trabaja por frecuecnia y no por conteo
plt.show()

# %%
sns.histplot(data=tips, x='tip', bins=15, cumulative=False, hue='sex', stat='probability')
#Probability, tengo la probabilidad entre 0 y 1, que puedo traducir a porcentaje
plt.show()

# %%
sns.histplot(data=tips, x='tip', bins=15, cumulative=False, hue='sex', stat='percent')

plt.show()

# %%
sns.histplot(data=tips, x='tip', bins=15, cumulative=False, hue='sex', stat='density')

plt.show()

# %%
#Otro parámetro es el multiple, determino como quiero presentar mis datos
sns.histplot(data=tips, x='tip', bins=15, cumulative=False, hue='sex', stat='count', multiple='stack')
#Stack, termina 1 y empieza el otro
plt.show()

# %%
#Otro parámetro es el multiple, determino como quiero presentar mis datos
sns.histplot(data=tips, x='tip', bins=15, cumulative=False, hue='sex', stat='count', multiple='layer')
#Layer, como habiamos visto antess
plt.show()

# %%
#Otro parámetro es el multiple, determino como quiero presentar mis datos
sns.histplot(data=tips, x='tip', bins=15, cumulative=False, hue='sex', stat='count', multiple='dodge')
#Uno al lado del otro
#Muy bueno para hacer comparativas de distribucion
plt.show()

# %%
#Otro parámetro es el multiple, determino como quiero presentar mis datos
sns.histplot(data=tips, x='tip', bins=15, cumulative=False, hue='sex', stat='count', multiple='fill')
#De cero a 1 dando toda la probabilidad
plt.show()

# %%
#Para graficos de densidad
sns.kdeplot(data=tips, x='tip', hue='sex', cumulative=False, shade=True, bw_adjust=1)
#Diagrama de densidad
#bw_adjust ajusta los parámetros en los ejes
plt.show()

# %%
#grafico escalonado
sns.ecdfplot(data=tips,x='tip',hue='sex', stat='count')
plt.show()

# %%
#Grafico de distribucion
sns.displot(data=tips,x='total_bill',y='tip',hue='smoker')
#Los mismos parámetros antes vistos funcionan en este tipo de grafico displot, puede facilitar el usarlo
plt.show()

# %% [markdown]
# ## Categóricos
# Graficar variables de texto

# %%
sns.countplot(data=tips,x='day', hue='sex')
#Cuantos registros tengo para esa variable categórica, segmentado por sexo
plt.show()

# %%
sns.countplot(data=tips,y='day', hue='sex')
#Puedo graficar en rjr y
plt.show()

# %%
sns.stripplot(data=tips,x='day',y='total_bill', hue='sex')
#dispersion del total de la cuenta por dias
plt.show()

# %%
plt.figure(figsize=(10,12)) #Puedo ajustar el tamaño para visualizar mejor
#Puedo separar los registros para visualizar mejor con el parámetro dodge
sns.stripplot(data=tips,x='day',y='total_bill', hue='sex',dodge=True)
#dispersion del total de la cuenta por dias
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.swarmplot(data=tips,x='day',y='total_bill', hue='sex',dodge=True)
#Muy similar, pero expandidos hacia lo ancho, para visualizar la concentración
#Así podemos encontrar insights de manera visual
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.boxplot(data=tips,x='day',y='total_bill', hue='sex',dodge=True)
plt.show()

# %%
#Puedo cmbinar gráficas
plt.figure(figsize=(6,6))
sns.boxplot(data=tips,x='day',y='total_bill', hue='sex',dodge=True)
sns.swarmplot(data=tips,x='day',y='total_bill', hue='sex',dodge=True, color="0",alpha=0.7)
#Puedo customizarlos
plt.show()

# %%
#Grafico de violines
plt.figure(figsize=(6,6))
sns.violinplot(data=tips,x='day',y='total_bill', hue='sex',dodge=True)
# Indica como se están concentrando los datos
#Puedo customizarlos
plt.show()

# %%
#Grafico de violines
plt.figure(figsize=(6,6))
sns.violinplot(data=tips,x='day',y='total_bill', hue='sex',split=True, palette='pastel')
# Con split los combina
#Puedo customizarlos
plt.show()

# %%
sns.violinplot(data=tips,y='total_bill', hue='sex', palette='pastel')
plt.show()

# %%
sns.catplot(data=tips,x='day',y='total_bill', hue='sex', dodge=True)
#Con catplot (de categorico), plotea el grafico categorico sin necesidad de indicarle el tipo
plt.show()

# %%
#Al igual que con displot, puedo usar kind para definir el tipo de grafico que quiero
#Usar catplot permite iterar distintas graficas con una simple llamada
sns.catplot(data=tips,x='day',y='total_bill', hue='sex', dodge=True,kind='box',col='time')
#Con col, puedo agregar otra columna de agrupación
#Con catplot (de categorico), plotea el grafico categorico sin necesidad de indicarle el tipo
plt.show()

# %% [markdown]
# ## Relation
# Relación o correlación entre variables numéricas

# %% [markdown]
# [Documentation](https://seaborn.pydata.org/generated/seaborn.relplot.html)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size')
#con Hue segmento en dias
#Con style, declaro que el estilo (forma de puntos) está definido por la variable time
#Con size defino el tamaño del simbolo en este caso con el numero de comenzales
plt.legend(loc='center',bbox_to_anchor=(1.10,0.5)) #para ubicar la legendsns.scatterplot(data=tips,x='total_bill',y='tip'
plt.show()

# %%
sns.pairplot(data=tips,hue='day')
'''
También podemos usar pairplot,
te permite ver comparativas de pares de variables y analizar su comportamiento en un solo gráfico.
'''
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Es bastante customizable
markers = {"Lunch":"D", "Dinner":"s"} #creo un diccionario de marker para añadir estilos a los puntos 
#cada estilo en seaborn tiene una nomenclatuta por ejemplo D es diamante y s es cuadrado (ver documentacion)
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size',markers=markers)
#agregando el diccionario a markers
plt.legend(loc='center',bbox_to_anchor=(1.10,0.5))
'''
loc='center': Especifica la ubicación de la leyenda en relación con el gráfico. En este caso, se establece en 'center', lo que significa que la leyenda se ubicará en el centro del gráfico. Otras opciones comunes son 'best', 'upper right', 'lower left', etc.
bbox_to_anchor=(1.10,0.5): Este parámetro es un poco más complejo. bbox_to_anchor es un parámetro que se utiliza para especificar la ubicación de la leyenda en relación con un rectángulo ( bounding box ) que rodea el gráfico.
En este caso, el valor (1.10,0.5) es una tupla que contiene dos valores:

1.10: Es el valor x (horizontal) que indica la posición de la leyenda en relación con el borde derecho del gráfico. Un valor de 1.10 significa que la leyenda se ubicará a la derecha del gráfico, a una distancia de 10% del ancho del gráfico.
0.5: Es el valor y (vertical) que indica la posición de la leyenda en relación con el borde superior del gráfico. Un valor de 0.5 significa que la leyenda se ubicará en el centro vertical del gráfico.
'''
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.lineplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size',markers=markers)
#se usa otro tipo de graficas similar pero con interlineado
plt.legend(loc='center',bbox_to_anchor=(1.10,0.5))

plt.show()

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size',col='time',kind='scatter')
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Jointplot y Pairplot
# Con un comando puedo combinar más de un tipo de gráfico.
# Muy útil para tener un overview inicial de los datos

# %%
sns.jointplot(data=tips,x='total_bill', y='tip')
plt.show()

# %%
#Costumizando
sns.jointplot(data=tips,x='total_bill', y='tip',hue='sex')
#seaborn lo adapata a lo que cree es mejor
plt.show()

# %%
#Costumizando
sns.jointplot(data=tips,x='total_bill', y='tip',hue='sex',kind='hist',marginal_ticks=True)
#con marginal le agrego valor a los graficos del margen
plt.show()

# %%
#Costumizando
sns.jointplot(data=tips,x='total_bill', y='tip',hue='sex',kind='hist',marginal_ticks=True, marginal_kws=dict(bins=25, fill=True, multiple='dodge'))
#con marginal le agrego valor a los graficos del margen
plt.show()

# %%
sns.pairplot(data=tips)
#Funciona para relacionar todas las variables numericas que se encuentran en un dataset
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(data=tips,hue='sex')
#Puedo agrupar por sexo con hue
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(data=tips,hue='sex',palette='coolwarm', corner=True)
#Puedo customizar; corner true elimina información duplicada, así solo tengo lo que importa
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Heatmap
# Especialmente útil para estructuras matriciales

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
heat=tips.corr(numeric_only=True)
heat
#Corr es una funcionalidad de Pandas para evaluar correlación entre variables
#Va de -1 a 1, correlación totalmente indirecta, 0= nula, 1=Correlación directa
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(heat)
plt.show()

# %%
#Dando mas contexto
sns.heatmap(heat,annot=True,cmap='coolwarm',linewidths=6,linecolor='lightgray',vmin=0.5,vmax=1,cbar=True)
#annot=coloca los valores en los recuadros
#linewidths separa un poco las lineas  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 #Dando mas contexto
# ----> 2 sns.heatmap(tips.corr(),annot=True,cmap='coolwarm',linewidths=6,linecolor='lightgray',vmin=0.5,vmax=1,cbar=True)
#       3 #annot=coloca los valores en los recuadros
#       4 #linewidths separa un poco las lineas
#       5 plt.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# ...
